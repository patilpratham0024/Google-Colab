# %% [markdown]
# <a href="https://colab.research.google.com/github/patilpratham0024/Google-Colab/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path  = r"/content/Luxury watch.csv"
for line in open(path):
    print(line)
# Out:
# ﻿Brand,Model,Case Material,Strap Material,Movement Type,Water Resistance,Case Diameter (mm),Case Thickness (mm),Band Width (mm),Dial Color,Crystal Material,Complications,Power Reserve,Price (USD)
#
# Rolex,Submariner,Stainless Steel,Stainless Steel,Automatic,300 meters,40,13,20,Black,Sapphire,Date,48 hours,"9,500"
#
# Omega,Seamaster,Titanium,Rubber,Automatic,600 meters,43.5,14.47,21,Blue,Sapphire,Date,60 hours,"5,800"
#
# Tag Heuer,Carrera,Stainless Steel,Leather,Automatic,100 meters,41,13,20,White,Sapphire,Chronograph,42 hours,"4,200"
#
# Breitling,Navitimer,Stainless Steel,Stainless Steel,Automatic,30 meters,43,14.25,22,Black,Sapphire,Chronograph,70 hours,"7,900"
#
# Cartier,Tank Solo,Stainless Steel,Leather,Quartz,30 meters,31,6.05,20,Silver,Sapphire,None,N/A,"2,800"
#
# Jaeger-LeCoultre,Reverso,Stainless Steel,Leather,Manual,30 meters,42.9,9.2,20,Black,Sapphire,None,45 hours,"5,500"
#
# ...

# %%
path  = r"/content/grocery.txt"
my_file = open(path)
my_file.readlines()
# Out:
# ['"1,Potato,10"\n',
#  '"2,Carrot,15"\n',
#  '"3,Coriander,20"\n',
#  '"4,Tomato,18"\n',
#  '"5,Cauliflower,22"\n',
#  '"6,Lettuce,30"\n',
#  '"7,Avocado,40"\n',
#  '"8,Watermelon,50"\n',
#  '"9,Lemon,20"\n',
#  '"10,Banana,20"\n']

# %%
with open(r"/content/grocery.txt") as my_file:
  print(my_file.readlines())
# Out:
# ['"1,Potato,10"\n', '"2,Carrot,15"\n', '"3,Coriander,20"\n', '"4,Tomato,18"\n', '"5,Cauliflower,22"\n', '"6,Lettuce,30"\n', '"7,Avocado,40"\n', '"8,Watermelon,50"\n', '"9,Lemon,20"\n', '"10,Banana,20"\n']

# %%
# For Reading and Writing
with open(r"/content/grocery.txt", mode = "r+") as my_file: 
  text = my_file.write("Hello")
  print(my_file.readlines())
# Out:
# ['Hello']

# %%
# for just reading the file mode suggests it is a default command
with open(r"/content/grocery.txt", mode = "r") as my_file:
  print(my_file.readlines())
# Out:
# ['HelloHello']

# %%
# for just appending in the file
with open(r"/content/grocery.txt", mode="w") as my_file:
  text = my_file.write("My Name Is Pratham")
